# %%
import pandas as pd
from datetime import datetime
import pytz
import smtplib
from email.message import EmailMessage

from openpyxl import load_workbook
from openpyxl.styles import Alignment


path = '/content/1733505423174.csv'
dataframe = pd.read_csv(path)
print(dataframe.shape)
# Out:
# (40981, 24)

# %%
#Agrupar por matricula y por rango


dataframe_1=dataframe[['Numero de contrato','Departamento','Ciudad','Identificador beneficiario','Grupo','Matricula','Zona','Velocidad de subida [Kbps]','Velocidad de bajada [Kbps]','Fecha de programacion','Fecha de ejecucion','Rango','Duracion de la prueba [s]','Dispositivo','Tipo de solucion','Tipo de centro digital','Estado de la prueba','Identificador de la prueba','Centro poblado','Dane institucion educativa','Tipo']]

matricula1 = dataframe_1[(dataframe_1['Matricula'] == "Matricula <= 50")]
matricula2 = dataframe_1[(dataframe_1['Matricula'] == "51 >= Matricula <= 150")]
matricula3 = dataframe_1[(dataframe_1['Matricula'] == "151 >= Matricula <= 400")]
matricula4 = dataframe_1[(dataframe_1['Matricula'] == "Matricula > 400")]

print(matricula1.shape)

matricula1_rango6 = matricula1[(matricula1['Rango'] == 6)]
matricula1_rango7 = matricula1[(matricula1['Rango'] == 7)]
matricula1_rango8 = matricula1[(matricula1['Rango'] == 8)]
matricula1_rango9 = matricula1[(matricula1['Rango'] == 9)]
matricula1_rango10 = matricula1[(matricula1['Rango'] == 10)]
matricula1_rango11 = matricula1[(matricula1['Rango'] == 11)]
matricula1_rango12 = matricula1[(matricula1['Rango'] == 12)]
matricula1_rango13 = matricula1[(matricula1['Rango'] == 13)]
matricula1_rango14 = matricula1[(matricula1['Rango'] == 14)]
matricula1_rango15 = matricula1[(matricula1['Rango'] == 15)]
matricula1_rango16 = matricula1[(matricula1['Rango'] == 16)]
matricula1_rango17 = matricula1[(matricula1['Rango'] == 17)]
matricula1_rango18 = matricula1[(matricula1['Rango'] == 18)]
matricula1_rango19 = matricula1[(matricula1['Rango'] == 19)]
matricula1_rango20 = matricula1[(matricula1['Rango'] == 20)]

matricula2_rango6 = matricula1[(matricula1['Rango'] == 6)]
matricula2_rango7 = matricula1[(matricula1['Rango'] == 7)]
matricula2_rango8 = matricula1[(matricula1['Rango'] == 8)]
matricula2_rango9 = matricula1[(matricula1['Rango'] == 9)]
matricula2_rango10 = matricula1[(matricula1['Rango'] == 10)]
matricula2_rango11 = matricula1[(matricula1['Rango'] == 11)]
matricula2_rango12 = matricula1[(matricula1['Rango'] == 12)]
matricula2_rango13 = matricula1[(matricula1['Rango'] == 13)]
matricula2_rango14 = matricula1[(matricula1['Rango'] == 14)]
matricula2_rango15 = matricula1[(matricula1['Rango'] == 15)]
matricula2_rango16 = matricula1[(matricula1['Rango'] == 16)]
matricula2_rango17 = matricula1[(matricula1['Rango'] == 17)]
matricula2_rango18 = matricula1[(matricula1['Rango'] == 18)]
matricula2_rango19 = matricula1[(matricula1['Rango'] == 19)]
matricula2_rango20 = matricula1[(matricula1['Rango'] == 20)]

matricula3_rango6 = matricula1[(matricula1['Rango'] == 6)]
matricula3_rango7 = matricula1[(matricula1['Rango'] == 7)]
matricula3_rango8 = matricula1[(matricula1['Rango'] == 8)]
matricula3_rango9 = matricula1[(matricula1['Rango'] == 9)]
matricula3_rango10 = matricula1[(matricula1['Rango'] == 10)]
matricula3_rango11 = matricula1[(matricula1['Rango'] == 11)]
matricula3_rango12 = matricula1[(matricula1['Rango'] == 12)]
matricula3_rango13 = matricula1[(matricula1['Rango'] == 13)]
matricula3_rango14 = matricula1[(matricula1['Rango'] == 14)]
matricula3_rango15 = matricula1[(matricula1['Rango'] == 15)]
matricula3_rango16 = matricula1[(matricula1['Rango'] == 16)]
matricula3_rango17 = matricula1[(matricula1['Rango'] == 17)]
matricula3_rango18 = matricula1[(matricula1['Rango'] == 18)]
matricula3_rango19 = matricula1[(matricula1['Rango'] == 19)]
matricula3_rango20 = matricula1[(matricula1['Rango'] == 20)]

matricula4_rango6 = matricula1[(matricula1['Rango'] == 6)]
matricula4_rango7 = matricula1[(matricula1['Rango'] == 7)]
matricula4_rango8 = matricula1[(matricula1['Rango'] == 8)]
matricula4_rango9 = matricula1[(matricula1['Rango'] == 9)]
matricula4_rango10 = matricula1[(matricula1['Rango'] == 10)]
matricula4_rango11 = matricula1[(matricula1['Rango'] == 11)]
matricula4_rango12 = matricula1[(matricula1['Rango'] == 12)]
matricula4_rango13 = matricula1[(matricula1['Rango'] == 13)]
matricula4_rango14 = matricula1[(matricula1['Rango'] == 14)]
matricula4_rango15 = matricula1[(matricula1['Rango'] == 15)]
matricula4_rango16 = matricula1[(matricula1['Rango'] == 16)]
matricula4_rango17 = matricula1[(matricula1['Rango'] == 17)]
matricula4_rango18 = matricula1[(matricula1['Rango'] == 18)]
matricula4_rango19 = matricula1[(matricula1['Rango'] == 19)]
matricula4_rango20 = matricula1[(matricula1['Rango'] == 20)]
# Out:
# (23183, 21)

# %%
# descargar y crear archiv ecxel por pestañas

output_path = '/content/20241031 Matricula <= 50.xlsx'
# Crear un archivo Excel con múltiples hojas
with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
    matricula1.to_excel(writer, sheet_name='Matricula <= 50', index=False, startrow=13)
    matricula1_rango6.to_excel(writer, sheet_name='6', index=False, startrow=13)
    matricula1_rango7.to_excel(writer, sheet_name='7', index=False, startrow=13)
    matricula1_rango8.to_excel(writer, sheet_name='8', index=False, startrow=13)
    matricula1_rango9.to_excel(writer, sheet_name='9', index=False, startrow=13)
    matricula1_rango10.to_excel(writer, sheet_name='10', index=False, startrow=13)
    matricula1_rango11.to_excel(writer, sheet_name='11', index=False, startrow=13)
    matricula1_rango12.to_excel(writer, sheet_name='12', index=False, startrow=13)
    matricula1_rango13.to_excel(writer, sheet_name='13', index=False, startrow=13)
    matricula1_rango14.to_excel(writer, sheet_name='14', index=False, startrow=13)
    matricula1_rango15.to_excel(writer, sheet_name='15', index=False, startrow=13)
    matricula1_rango16.to_excel(writer, sheet_name='16', index=False, startrow=13)
    matricula1_rango17.to_excel(writer, sheet_name='17', index=False, startrow=13)
    matricula1_rango18.to_excel(writer, sheet_name='18', index=False, startrow=13)
    matricula1_rango19.to_excel(writer, sheet_name='19', index=False, startrow=13)
    matricula1_rango20.to_excel(writer, sheet_name='20', index=False, startrow=13)

print(f"Archivo guardado en: {output_path}")

wb = load_workbook(output_path)

# Definir el título principal que se quiere poner en todas las hojas
main_title = "2.3.4.4.2 VELOCIDAD EFECTIVA MÍNIMA DE TRANSMISIÓN DE DATOS"

# Definir los subtítulos (para la fila 2 y siguientes)
sub_titles = ["Año-Mes(AAAA-MM)"]
sub_titles2 = ["2024-10"]
sub_titles3 = ["Sentido","Matricula","Velocidad Por Matricula","Posición de la prueba","Prueba P5%","Resultado","Posición de la prueba","Prueba P95%","Resultado"]
sub_titles4 = ["Dowload","51 >= Matricula <= 150"]
sub_titles5 = ["Sentido","Matricula","Velocidad Por Matricula","Posición de la prueba","Prueba P5%","Resultado","Posición de la prueba","Prueba P95%","Resultado"]
sub_titles6 = ["Upload","51 >= Matricula <= 150"]




for sheet_name in wb.sheetnames:
    sheet = wb[sheet_name]

    # Colocar el título principal en la fila 1, combinado a través de un rango adecuado
    sheet.merge_cells('A1:V1')  # Ajusta el rango de celdas según el número de columnas en tus datos
    sheet['A1'] = main_title
    sheet['A1'].alignment = Alignment(horizontal="center", vertical="center")

    # Colocar los subtítulos en la fila 2 (columnas A, B, C, etc.)
    for col, sub_title1 in zip(['B'], sub_titles):
        sheet[f'{col}3'] = sub_title1
        sheet[f'{col}3'].alignment = Alignment(horizontal="center", vertical="center")

    # Colocar los subtítulos en la fila 2 (columnas A, B, C, etc.)
    for col, sub_title2 in zip(['B'], sub_titles2):
        sheet[f'{col}4'] = sub_title2
        sheet[f'{col}4'].alignment = Alignment(horizontal="center", vertical="center")

    # Colocar los subtítulos en la fila 2 (columnas A, B, C, etc.)
    columns = ['B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']
    for col, sub_title3 in zip(columns, sub_titles3):
        sheet[f'{col}6'] = sub_title3
        sheet[f'{col}6'].alignment = Alignment(horizontal="center", vertical="center")
    # Colocar los subtítulos en la fila 2 (columnas A, B, C, etc.)
    columns=['B','C']
    for col, sub_title4 in zip(columns, sub_titles4):
        sheet[f'{col}7'] = sub_title4
        sheet[f'{col}7'].alignment = Alignment(horizontal="center", vertical="center")

    # Colocar los subtítulos en la fila 2 (columnas A, B, C, etc.)
    columns = ['B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']
    for col, sub_title5 in zip(columns, sub_titles5):
        sheet[f'{col}9'] = sub_title5
        sheet[f'{col}9'].alignment = Alignment(horizontal="center", vertical="center")

    columns=['B','C']
    for col, sub_title6 in zip(columns, sub_titles6):
        sheet[f'{col}10'] = sub_title6
        sheet[f'{col}10'].alignment = Alignment(horizontal="center", vertical="center")



# Guardar el archivo actualizado
wb.save(output_path)

# Descargar el archivo a tu máquina local
from google.colab import files
files.download(output_path)



# Descargar el archivo a tu máquina local
from google.colab import files
files.download(output_path)
# Out:
# Archivo guardado en: /content/20241031 Matricula <= 50.xlsx

# %%
dataframe = pd.DataFrame(data,columns=data.columns)
